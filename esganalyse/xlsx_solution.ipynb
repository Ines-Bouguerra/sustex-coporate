# %%
import pandas as pd

# Path to the Excel file
file_path = 'D:\IA\sustex-coporate\Schneider Data.xlsx'

# Load the Excel file
excel_file = pd.ExcelFile(file_path)

# Get all sheet names
sheet_names = excel_file.sheet_names
print("Sheet names:", sheet_names)
# for name in sheet_names:
#     # Read a specific sheet (for example, the first sheet)
#     df = pd.read_excel(file_path, sheet_name=name, header=None, index_col=None)
#     print(df)
# Out:
# Sheet names: ['Sheet1']

# %%
df = (pd.read_excel(file_path, sheet_name="Sheet1")
        )
df
# Out:
#                                               Category  \
# 0    Perimeter and Environmental Management Systems...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                     Group site consumption emissions
# ..                                                 ...
# 389                                                NaN
# 390                                                NaN
# 391                                                NaN
# 392                                                NaN
# 393          Total budget for the Foundation’s actions
#
#                                              Indicator Units      2022  \
# 0                        Sites certifiés ISO 14001 (1)     #       243
# 1                     Sites industriels et logistiques     #       204
# 2                                     Sites tertiaires     #        39
# ...

# %%
# df = (pd.read_excel(file_path, skiprows=1, sheet_name="Sheet1")
#         .dropna(how='all', axis=1))
# # df

# df_trimmed = df.dropna(axis=0, how='all').dropna(axis=1, how='all')
# df_trimmed
# Out:
#     Perimeter and Environmental Management Systems (ISO 14001)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                     Group site consumption emissions
# 4                                                  NaN
# ..                                                 ...
# 388                                                NaN
# 389                                                NaN
# 390                                                NaN
# 391                                                NaN
# 392          Total budget for the Foundation’s actions
#
#                          Sites certifiés ISO 14001 (1)  #       243       244  \
# 0                     Sites industriels et logistiques  #       204       211
# 1                                     Sites tertiaires  #        39        33
# ...

# %%
last_line = df_trimmed.tail(40)
last_line
# Out:
#       Environment                                         Unnamed: 3  \
# 80            NaN                        ▲ Indicateurs 2022 audités.
# 82            NaN                                            Energie
# 83            GRI                                        Indicateurs
# 84            NaN  Taux de couverture estimé (% consommations d'é...
# 85            NaN                          Sites certifiés ISO 50001
# 86   302-1, 302-4              Consommation d’énergie totale estimée
# 87   302-1, 302-4                dont consommation d’énergie mesurée
# 88            NaN  dont consommation d’énergie estimée pour les s...
# 89   302-1, 302-4  Consommation d’énergie estimée totale par chif...
# 90            NaN                   Productivité énergétique estimée
# 91            NaN  Amélioration totale en productivité énergétiqu...
# 92            NaN  Consommation d’énergie totale estimée de sourc...
# 93            NaN          Pourcentage d’énergie renouvelable estimé
# ...

# %%
# Read the Excel file without using the first row as the header
#Read the Excel file skipping the first few rows (including the header)
df = pd.read_excel(file_path, sheet_name="Sheet1",header=None)
df.drop(df.columns[0], axis=1)
df
# # Drop rows and columns that contain only missing values (NaNs)
# df_trimmed = df.dropna(axis=0, how='all').dropna(axis=1, how='all')

# # Reset index to clean up the index after dropping the header and empty rows
# df_trimmed.reset_index(drop=True, inplace=True)
# df_trimmed
# Out:
#      0   1                                                  2   \
# 0   NaN NaN                                                NaN
# 1   NaN NaN                                        Environment
# 2   NaN NaN                                      Environnement
# 3   NaN NaN  The indicators below concern all entities wher...
# 4   NaN NaN                                                NaN
# ..   ..  ..                                                ...
# 131 NaN NaN                                       Useful Links
# 132 NaN NaN                                                NaN
# 133 NaN NaN                                                NaN
# 134 NaN NaN                                                NaN
# 135 NaN NaN                                                NaN
#
#                                                 3   \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# ...

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['Environment', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11']
